# %%
# Basic python syntax, comments

# %%
# Taking user i/p.

# python uses input() function to read user i/p.

x = input("enter any no.")
# Out:
# enter any no. 2

# %%
# printing o/p.

# python uses print() function to return the o/p.

print(x)
# Out:
# 2

# %%
# comments in python.

#python uses # to comment a single line.

# print(x)

# %%
# multi-line commrnts.

#no particular syntax for multi-line comments. but we can enclose the lines with " " so python confuses it as a string but without assigning it to a variable it doesn't execute the lines.

"print(x)"
# Out:
# 'print(x)'

# %%
# variables in Python.

# Variables are containers for storing data values.

# Unlike other programming languages, Python has no command for declaring a variable.

# A variable is created the moment you first assign a value to it.

x = 5

# %%
# Variables do not need to be declared with any particular type.

x = 5
print(x)
# Out:
# 5

# %%
# variables can even change type and values after they have been set.

x = 5
print(x)
x = ("Saurav")
print(type(x))
# Out:
# 5
# <class 'str'>

# %%
# Variables are case sensitive.

var = 5
print(var)
Var = 10
print(Var)
# Out:
# 5
# 10

# %%
# Python allows to assign values to multiple variables in a sinle line.

x, y, z = 5, 10, 20

print(x)
print(y)
print(z)
# Out:
# 5
# 10
# 20

# %%
# Python also allows to assiggn a single value to different variables.

x = y= z = 100
print(x)
print(y)
print(z)
# Out:
# 100
# 100
# 100
